# %% [markdown]
# ## Scratch pad for initial CAL foundation directory work with Will

# %%
import geopandas as gpd
import os
import pandas as pd
from typing import List, Dict
from pathlib import Path
import matplotlib.pyplot as plt
from utils.data import contains_substring, replace_lots
from utils.io import xls_to_csvs
from utils.gpd import df_to_gdf
from utils.location import city_lat_lon


import warnings
import datetime as dt

warnings.filterwarnings("ignore")
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
# combine lists

# %%
# Oil and gas watch data has CO2 sites/pipelines not in the EIA databases

# get ogw data and split it into CSVs:
xls_to_csvs(
    "/Volumes/T5_External/data/oilgas/ogw/ogw_export_20250707.xlsx",
    "/Volumes/T5_External/data/oilgas/ogw",
)

# %% [markdown]
# ### Define fit-for-purpose functions

# %%
def read_geojson_files(folder_path: str) -> Dict[gpd.GeoDataFrame]:
    """
    Reads all geojson files in the specified folder and returns a dict of GeoDataFrames.

    Args:
        folder_path: The path to the folder containing GeoJSON files.
    Returns:
        list of gdfs from the file
    """
    gdf_dict = dict()

    # Iterate through all files in the specified folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".geojson"):
            file_path = os.path.join(folder_path, filename)
            # Read the GeoJSON file into a GeoDataFrame
            gdf = gpd.read_file(file_path)
            gdf_dict[filename.rsplit("_", 1)[0]] = gdf
            # geo_dataframes.append(gdf)
            print(f"Loaded {filename} with {len(gdf)} features.")

    return gdf_dict

# %% [markdown]
# ### Get data

# %%
# get the OGW projects data
projects_df = pd.read_csv("/Volumes/T5_External/data/oilgas/ogw/projects.csv")
projects_df.columns = [replace_lots(x.lower()) for x in projects_df.columns.values]
projects_gdf = df_to_gdf(projects_df)
projects_gdf.company.fillna("", inplace=True)

# get the OGW list of UIC permit locations
uic_df = pd.read_csv("/Volumes/T5_External/data/oilgas/ogw/uic_permits.csv")
uic_df.columns = [replace_lots(x.lower()) for x in uic_df.columns.values]
uic_gdf = df_to_gdf(uic_df, lat="well_latitude", lon="well_longitude")
uic_gdf.facility.fillna("", inplace=True)

# %%
# Read in EIA data
gdf_dict = read_geojson_files("/Volumes/T5_External/data/eia")
# Out:
# Loaded CoalMines_US_EIA_3371837949864749161.geojson with 560 features.
# Loaded Petroleum_Refineries_US_EIA_-8500459705133754478 1.geojson with 132 features.
# Loaded Power_Plants.geojson with 13446 features.
# Loaded PetroleumProduct_Terminals_US_EIA_-1807265316411812248.geojson with 1459 features.
# Loaded Ethylene_Crackers_US_EIA_-3527313759907648060.geojson with 35 features.
# Loaded NaturalGas_InterIntrastate_Pipelines_US_EIA_-6673208179901703463.geojson with 32892 features.
# Loaded Hydrocarbon_Gas_Liquids_(HGL)_Market_Hubs.geojson with 3 features.
# Loaded HGL_Pipelines_US_EIA_-4268877595463524252.geojson with 133 features.
# Loaded NaturalGas_ProcessingPlants_US_EIA_-1067528654751822058.geojson with 478 features.
# Loaded Market_Hubs_Natural_Gas_3946026054909568455.geojson with 32 features.
# Loaded Lng_ImportExportTerminals_US_EIA_-6607817115306832346.geojson with 9 features.
# Loaded Petroleum_Refineries_US_EIA_-8500459705133754478.geojson with 132 features.
# Loaded CrudeOil_Pipelines_US_EIA_3804557837623292923.geojson with 236 features.

# %%
# company_list = ["eqt", "equitrans", "rice", "equitable"] # EQT companies/former names

# ExxonMobil company name substrings (including subsidiaries)
company_list = ["exxon", "xto ", "denbury", "pioneer"]

# %%
refinery_gdf = gdf_dict["Petroleum_Refineries_US_EIA"]
[
    x
    for x in list(refinery_gdf.Corp.unique())
    if contains_substring(
        x,
        company_list,
    )
]
# Out:
# []

# %%
power_gdf = gdf_dict["Power"]
[
    x
    for x in list(power_gdf.Utility_Name.unique())
    if contains_substring(
        x,
        company_list,
    )
]
# Out:
# ['Rice University', 'MSC-Rice01 LLC', 'Rice Community Solar Two LLC']

# %%
ng_pipeline_gdf = gdf_dict["NaturalGas_InterIntrastate_Pipelines_US_EIA"]
[
    x
    for x in list(ng_pipeline_gdf.Operator.unique())
    if contains_substring(x, company_list)
]
# Out:
# ['Equitrans Inc']

# %%
for i in gdf_dict.keys():
    print(i)

# %%
companies = [
    x for x in uic_df.facility.unique() if contains_substring(x, company_list)
] + [x for x in projects_gdf.company.unique() if contains_substring(x, company_list)]

# %%
names = {
    "Ethylene_Crackers_US_EIA": {
        "company": {"ExxonMobil": ["Exxon/SABIC", "ExxonMobil Chemical Co."]},
        "column_name": "COMPANY",
    },
    "Petroleum_Refineries_US_EIA": {
        "company": {"ExxonMobil": ["EXXON MOBIL CORP"]},
        "column_name": "Corp",
    },
    "Power": {
        "company": {
            "ExxonMobil": [
                "Exxon Mobil Refining and Supply Co.",
                "Exxon Mobil Corp",
                "Exxon Mobil Production Co",
                "ExxonMobil Oil Corp",
                "Denbury Inc",
            ]
        },
        "column_name": "Utility_Name",
    },
    "NaturalGas_ProcessingPlants_US_EIA": {
        "company": {
            "ExxonMobil": [
                "XTO Energy, Inc.",
                "XTO Energy, INC",
                "Exxon",
                "ExxonMobil Corporation",
                "XTO Energy",
            ]
        },
        "column_name": "Owner",
    },
    "CrudeOil_Pipelines_US_EIA": {
        "company": {"ExxonMobil": ["EXXONMOBIL", "EXXONMOBIL WEST COAST"]},
        "column_name": "Opername",
    },
}

# %%
for d in list(gdf_dict.keys()):
    print(d)
# Out:
# CoalMines_US_EIA
# Petroleum_Refineries_US_EIA
# Power
# PetroleumProduct_Terminals_US_EIA
# Ethylene_Crackers_US_EIA
# NaturalGas_InterIntrastate_Pipelines_US_EIA
# Hydrocarbon_Gas_Liquids_(HGL)_Market
# HGL_Pipelines_US_EIA
# NaturalGas_ProcessingPlants_US_EIA
# Market_Hubs_Natural_Gas
# Lng_ImportExportTerminals_US_EIA
# CrudeOil_Pipelines_US_EIA

# %%
gdf_dict["Petroleum_Refineries_US_EIA"]

# %%
exxon_list = []
for name, tree in names.items():
    print(name)
    gdf = gdf_dict[name]
    col = tree["column_name"]
    tmp_gdf = gdf[[col, "geometry"]].loc[gdf[col].isin(tree["company"]["ExxonMobil"])]
    tmp_gdf["infrastructure_type"] = name
    exxon_list.append(tmp_gdf)
    del tmp_gdf, gdf

exxon_gdf = gpd.GeoDataFrame(pd.concat(exxon_list), geometry="geometry")
# Out:
# Ethylene_Crackers_US_EIA
# Petroleum_Refineries_US_EIA
# Power
# NaturalGas_ProcessingPlants_US_EIA
# CrudeOil_Pipelines_US_EIA

# %%
# get US state outlines
DATA_DIR = Path("/Volumes/T5_External/data")
us_gdf = gpd.read_file(DATA_DIR / Path("us_geo/us_states.json"))

# %%
xom_pipelines = pipelines_df.loc[pipelines_df.company.isin(pipeline_companies)][
    "pipeline_ogw_id"
].to_list()

# %%
sorted(list(pipe_gdf.prjname.unique()))
# Out:
# ['134th Street Lateral Project',
#  '2021 Auburn A-line Abandonment and Capacity Replacement Project',
#  '261 Upgrade Projects',
#  'ADCC Pipeline',
#  'Adelphia Gateway Project',
#  'Aegis Ethane Pipeline',
#  'Agua Blanca Pipeline',
#  'Air Products CO2 Pipeline',
#  'Air Products Hydrogen Lateral',
#  'Air Products Natural Gas Pipeline',
#  'Alaska Nikiski LNG Pipeline',
#  'Apex Pipeline',
#  'Appalachia to Market II and Replacement Project',
#  'Appalachia to Market Project',
#  'Atlantic Bridge Project',
#  'Bahia NGL Pipeline',
#  'Bailey East Mine Panel 11J Project',
#  'Baymark Pipeline',
#  'Black Bayou Gas Storage Project',
#  'Blackcomb Pipeline',
#  'Blackfin Pipeline',
#  'Blue Marlin Offshore Port (BMOP) Pipelines',
#  'Blue Water Energy Center (BWEC) Pipeline',
#  'Bluewater Texas Terminals (BTWX) Pipelines',
#  'Borger Express Pipeline',
#  'Buckeye Xpress',
#  'Buncombe County Enhancement Project',
#  'CJ Express Expansion Project',
#  'CP Express Pipeline Project',
#  'Cameron Extension Project',
#  'Cameron Pipeline Expansion Project',
#  'Carlsbad South Project',
#  'Cheyenne Connector Pipeline and Cheyenne Hub Enhancement Project',
#  'Commonwealth Energy Connector Project',
#  'Commonwealth LNG Pipeline',
#  'Corpus Christi CO2 Pipeline',
#  'Corpus Christi LNG',
#  'Corpus Christi Stage III Pipeline',
#  'Crow Creek Pipeline',
#  'Cumberland Project',
#  "D'Lo Gas Storage Project",
#  'Daytona NGLs Pipeline',
#  'DeLa Express Pipeline',
#  'Del-Mar Energy Pathway',
#  'Delfin LNG Onshore & Offshore Pipelines',
#  'Delta Express Pipeline Project',
#  'Delta Lateral Project',
#  'Denbury Green Pipeline',
#  'Denbury Green to CHW Ascension Clean Energy Project',
#  'Des Moines A-line Capacity Replacement Project',
#  'Diamondback Brownsville Expansion Project',
#  'Dominion West Loop Project',
#  'Double E Pipeline',
#  'Driftwood LNG Pipeline',
#  'Driftwood Line 200 and Line 300 Project',
#  'EPIC Ethane Pipeline - Corpus Christi/Robstown to Taft',
#  'East Cheyenne Gas Storage Expansion Project',
#  'East Lateral Xpress Project',
#  'East Tennessee NaturalGas Alignment Program',
#  'Eastern Panhandle Expansion Project',
#  'EnLink CO2 Pipeline',
#  'Enbridge Line 3 Replacement Project',
#  'Enbridge Line 5 Great Lakes Tunnel Project',
#  'Enbridge Line 5 Wisconsin Relocation Project',
#  'Epic NGL Pipeline - Corpus Christi/Robstown to Sweeny',
#  'Evangeline Pass Expansion Project',
#  'FM100 Project',
#  'Falcon Ethane Pipeline System',
#  'Freeport LNG - Train 4 Project',
#  'Galveston County Project',
#  'Gator Express Meter Project (Line 40 Connection)',
#  'Gator Express Pipeline Project',
#  'Grand Prix NGL Pipeline System',
#  'Grasslands South Expansion Project',
#  'Great Basin 2024 Expansion Project',
#  'Gulf Coast Express Pipeline',
#  'Gulf Run Pipeline and Line CP Modifications Project',
#  'Gulfstream Phase VI Expansion Project',
#  'Hackberry Pipeline & LA Storage Project',
#  'Hackberry Sequestration CO2 Pipeline',
#  'Heartland Project',
#  'Henderson County Expansion Project',
#  'Index 99 Expansion Project',
#  'Jupiter Pipeline',
#  'Keystone Port Neches Link',
#  'LA-122 and LA-122A CO2 Pipeline Lateral',
#  'Lake Charles LNG Pipeline Modifications Project',
#  'Lake Charles Pipeline Expansion Project',
#  'Lake City 1st Branch Line Abandonment and Capacity Replacement Project',
#  'Lamar County Expansion Project',
#  'Leidy South Project',
#  'Line 8000 Replacement Project',
#  'Line SM-116 Forced Relocation Project',
#  'Line Section 22 Project',
#  'Line YM28 & Line FM120 Modernization Project',
#  'Livingston Parish Sequestration Hub CO2 Pipeline',
#  'Lockridge Extension Pipeline',
#  'MASS Project',
#  'MVP Southgate Project',
#  'Magellan Pipeline System Expansion',
#  'Magnum Gas Storage Project',
#  'Mainline 300 Replacement Project',
#  'Mariner East II',
#  'Marshall County Mine Panels 19E and 20E Projects',
#  'Martin County Lateral',
#  'Matterhorn Express Pipeline (MXP)',
#  'Midcontinent Supply Header Interstate Pipeline Project',
#  'Middlesex Extension Project',
#  'Mountain Valley Pipeline and Equitans Expansion Project',
#  'NG3 Pipeline',
#  'Navigator Heartland Greenway CO2 Pipeline',
#  'New Burgos Pipeline',
#  'New Lisbon 2020 Expansion Project',
#  'North Bakken Expansion Project',
#  'Northeast Supply Enhancement Project',
#  'Northern Access 2016 Project',
#  'Northern Delaware Basin Expansion Project',
#  'Northern Lights 2019 Expansion and Rochester Projects',
#  'Northern Lights 2021 Expansion',
#  'Northern Lights 2023 Expansion',
#  'Northern Lights 2025 Expansion Project',
#  'Ohio Valley Connector Expansion',
#  'One Earth Sequestration (OES) Pipeline',
#  'Ozark Supply Access Pipeline',
#  'Pamplico Pipeline',
#  'Pennyrile Pipeline',
#  'Permian Highway Pipeline',
#  'Permico Companero Pipeline',
#  'Pikka Sales Oil Pipeline',
#  'Pimmit Hills Pipeline',
#  'Pineywoods CO2 Pipeline',
#  'Port Arthur Liquefaction Project - Texas Connector, Louisiana Connector, and Louisiana Connector Amendment Projects',
#  'Putnam Expansion Project',
#  'Red Hill Lateral Project',
#  'Regional Energy Access (REAE) Project',
#  'Ridgeline Expansion Project',
#  'Rio Bravo Pipeline Project',
#  'River Parish CO2 Pipeline',
#  'Sabine Crossing Pipeline',
#  'Sabine Pass Expansion Project',
#  'Sea Port Oil Terminal (SPOT) Onshore & Offshore Pipelines',
#  'Seahawk Pipeline - Blackhawk Pipeline',
#  'Seahawk Pipeline - Nighthawk Lateral',
#  'Seahorse Pipeline',
#  'Sendero Carlsbad Gateway Project',
#  'Shin Oak NGL Pipeline',
#  'South Bend Pipeline',
#  'South Mainline Expansion Project',
#  'South Sioux City to Sioux Falls A-line Replacement Project',
#  'Southeast Energy Connector Project',
#  'Southeast Market Pipeline Project (Sabal Trail Project, Hillabee Expansion Project, Florida Southeast Connection Project)',
#  'Southeast Supply Enhancement Project',
#  'Southeastern Trail Expansion Project',
#  'Spire STL Pipeline',
#  'Stateline-to-Riverview Tioga Lateral',
#  'Summit Carbon Solutions Midwest Carbon Express',
#  'Swordfish Pipeline',
#  'T15 Reliability Project',
#  'Texas Gulflink Pipeline',
#  'Three Rivers Interconnection Project',
#  'Tioga to Emerson',
#  'Trailblazer Conversion Project (Carbon Dioxide Component)',
#  'TransCameron East Lateral Pipeline Project',
#  'Tri-West Project',
#  'Utopia Pipeline',
#  'Valley Crossing Pipeline Expansion',
#  'Venice Extension Project',
#  'Virginia Reliability Project',
#  'Vito Oil Pipeline',
#  'Voyager Pipeline',
#  'Wahpeton Expansion Project',
#  'Warrior Pipeline',
#  'West Delta LNG Pipeline Project',
#  'Western Massachusetts Gas Reliability Project',
#  'Whistler Pipeline and Midland Lateral',
#  'Willis Lateral Project',
#  'Wisconsin Reliability Project',
#  'Wolf CO2 Pipeline Mt. Simon Hub']

# %%
xom_pipe_names = [
    "Denbury Green Pipeline",
    "Denbury Green to CHW Ascension Clean Energy Project",
    "Corpus Christi CO2 Pipeline",
    "Gulf Coast Express Pipeline",
    "Permian Highway Pipeline",
    "Whistler Pipeline and Midland Lateral",
]

# %%
pipelines_gdf.to_crs(exxon_gdf.crs, inplace=True)
pipe_gdf.to_crs(exxon_gdf.crs, inplace=True)

# %%
univ_df = pd.read_csv(
    "/Users/lindseygulden/dev/REFUSE/outputs/cleaned_university_data.csv"
)
univ_df.columns = [replace_lots(x.lower()) for x in univ_df.columns.values]

# %%
sorted(list(univ_df.parent_grantmaker.unique()))
# Out:
# ['ADOLPH COORS FOUNDATION',
#  'ANNENBERG FOUNDATION',
#  'ANSCHUTZ FOUNDATION THE',
#  'Acton Institute for The Study of Religion And Liberty',
#  'Alabama Power',
#  'Alliant Energy Corporation',
#  'Ameren Corporation',
#  'American Airlines Group Inc.',
#  'American Association of Petroleum Geologists',
#  'American Electric Power',
#  'American Enterprise Institute for Public Policy Research',
#  'American Gas Association',
#  'American Petroleum Institute',
#  'American Public Power Association',
#  'Anadarko',
#  'Apache',
#  'ArcelorMittal',
#  'Arch Resources',
#  'Association Of American Railroads',
#  'Atlas Network',
#  'BETH AND RAVENEL CURRY FOUNDATION',
#  'BHP',
#  'BILL AND MELINDA GATES FOUNDATION',
#  'BP',
#  'BRADY EDUCATION FOUNDATION, INC.',
#  'Berkshire Hathaway Energy',
#  'Black Hills Corporation',
#  'Boeing Company',
#  'CEMEX S.A.B. de C.V.',
#  'CMS Energy Corporation',
#  'CSX Transportation',
#  'Coca-Cola Company',
#  'Cummins Inc.',
#  'DANIELS FUND',
#  'DTE Energy Co',
#  'Davis family Foundations',
#  'Delta Air Lines, Inc.',
#  'Devos Family Foundations',
#  'Discovery Institute',
#  'Dominion Energy Inc',
#  'Donors Trust',
#  'Donors capital fund',
#  'Dow Inc.',
#  'Duke Energy',
#  'Dunn Foundation',
#  'EQT Corporation',
#  'Edison Electric Institute',
#  'Edison International',
#  'EnCana',
#  'Energy Transfer',
#  'Entergy',
#  'Equitrans Midstream Corporation',
#  'Exelon Corporation',
#  'ExxonMobil',
#  'FIDELITY CHARITABLE GIFT FUND',
#  'Federalist Society',
#  'FirstEnergy Corp',
#  'Ford Motor Company',
#  'Georgia Power',
#  'HERRICK FOUNDATION',
#  'HERTOG FOUNDATION',
#  'Hess Corporation',
#  'Hill & Knowlton',
#  'Hitachi, Ltd.',
#  'Honda Motor Company',
#  'Howard Charitable',
#  'International Paper Company, The',
#  'JAQUELIN HUME FOUNDATION',
#  'JOHN TEMPLETON FOUNDATION',
#  'JOHN WILLIAM POPE FOUNDATION',
#  'KERN FAMILY FOUNDATION',
#  'KKR',
#  'Kiewit Mining Group',
#  'Kinder Morgan',
#  'Koch',
#  'Kovner foundation',
#  'LILLIAN S. WELLS FOUNDATION, INC.',
#  'LILLY ENDOWMENT INC.',
#  'Lakeside Foundation',
#  'Liberty Fund',
#  'Lockheed Martin Corporation',
#  'Lynde and Harry Bradley Foundation',
#  'M.J. MURDOCK CHARITABLE TRUST',
#  'MDU Resources Group Inc',
#  'MERCER FAMILY FOUNDATION',
#  'Marathon Oil Corporation',
#  'Marathon Petroleum Corporation',
#  'Mercatus Center',
#  'Mitsubishi',
#  'Mitsui',
#  'NATIONAL CHRISTIAN CHARITABLE FOUNDATION INC',
#  'NATIONAL PHILANTHROPIC TRUST',
#  'NOBLE RESEARCH INSTITUTE, LLC',
#  'National Fuel Gas Company',
#  'National Grid',
#  'Nestle S.A.',
#  'NextEra Energy',
#  'Nissan Motor Co., Ltd.,',
#  'Norfolk Southern',
#  'Ogilvy',
#  'Oklahoma Energy Education Foundation',
#  'PACCAR Inc',
#  'PHARMACEUTICAL RESEARCH AND MANUFACTURERS OF AMERICA',
#  'PPL Corporation',
#  'PacifiCorp',
#  'PepsiCo, Inc.',
#  'Pioneer Natural Resources',
#  'QEP Resources',
#  'ROE FOUNDATION THE',
#  'Richard and Barbara Gaby Foundation',
#  'SMITH RICHARDSON FOUNDATION',
#  'SSAB AB',
#  'Scaife Family Foundations',
#  'Schwab Charitable Foundation',
#  'Searle Freedom Trust',
#  'Sempra Energy',
#  'Shell',
#  'Siemens AG',
#  'Southern Company',
#  'Sumitomo',
#  'TC Energy Corporation',
#  'THOMAS W SMITH FOUNDATION INC',
#  'The Roberts Foundation',
#  'Toyota',
#  'Trane Technologies PLC',
#  'U.S. JUSTICE CHARITABLE FOUNDATION, INC.',
#  'US Chamber of Commerce Foundation',
#  'Unilever PLC',
#  'Union Pacific',
#  'United Airlines Holdings, Inc.',
#  'United Mine Workers',
#  'VANGUARD CHARITABLE ENDOWMENT PROGRAM',
#  'Valero Energy Corporation',
#  'WALTON FAMILY FOUNDATION',
#  'WEC Energy Group, inc',
#  'WILLIAM AND FLORA HEWLETT FOUNDATION THE',
#  'WILLIAM E. SIMON FOUNDATION, INC.',
#  'WILLIAM K. BOWES, JR. FOUNDATION',
#  'Weyerhaeuser Company, The',
#  'Xcel Energy']

# %%
univ_df[["grant_amount", "parent_grantmaker"]].groupby(
    "parent_grantmaker"
).sum().sort_values(by="grant_amount", ascending=False).head(60)
# Out:
#                                               grant_amount
# parent_grantmaker
# FIDELITY CHARITABLE GIFT FUND                 3.127681e+09
# LILLY ENDOWMENT INC.                          1.892807e+09
# BILL AND MELINDA GATES FOUNDATION             1.523711e+09
# NATIONAL PHILANTHROPIC TRUST                  5.397109e+08
# JOHN TEMPLETON FOUNDATION                     5.320183e+08
# VANGUARD CHARITABLE ENDOWMENT PROGRAM         5.234881e+08
# Koch                                          4.570376e+08
# WILLIAM AND FLORA HEWLETT FOUNDATION THE      3.100677e+08
# WALTON FAMILY FOUNDATION                      2.928186e+08
# ANNENBERG FOUNDATION                          2.349359e+08
# DANIELS FUND                                  2.141791e+08
# Davis family Foundations                      1.916316e+08
# Devos Family Foundations                      1.898044e+08
# KERN FAMILY FOUNDATION                        1.592142e+08
# WILLIAM K. BOWES, JR. FOUNDATION              1.277828e+08
# ANSCHUTZ FOUNDATION THE                       1.257817e+08
# NATIONAL CHRISTIAN CHARITABLE FOUNDATION INC  1.160796e+08
# M.J. MURDOCK CHARITABLE TRUST                 1.057202e+08
# Hess Corporation                              9.670250e+07
# Kovner foundation                             7.422409e+07
# Ford Motor Company                            6.911209e+07
# Coca-Cola Company                             6.298732e+07
# SMITH RICHARDSON FOUNDATION                   6.279369e+07
# Scaife Family Foundations                     5.992104e+07
# BP                                            5.888062e+07
# ExxonMobil                                    5.844043e+07
# Shell                                         5.687135e+07
# The Roberts Foundation                        5.643110e+07
# Southern Company                              5.425930e+07
# Duke Energy                                   5.255296e+07
# Dow Inc.                                      5.126413e+07
# Alabama Power                                 3.158672e+07
# Lynde and Harry Bradley Foundation            3.135994e+07
# Mercatus Center                               3.102144e+07
# PepsiCo, Inc.                                 2.728302e+07
# Dominion Energy Inc                           2.606025e+07
# American Electric Power                       2.362890e+07
# Searle Freedom Trust                          2.122125e+07
# Donors Trust                                  1.950337e+07
# PACCAR Inc                                    1.842343e+07
# WEC Energy Group, inc                         1.702300e+07
# Delta Air Lines, Inc.                         1.584699e+07
# WILLIAM E. SIMON FOUNDATION, INC.             1.346104e+07
# DTE Energy Co                                 1.335053e+07
# JOHN WILLIAM POPE FOUNDATION                  1.326483e+07
# Georgia Power                                 1.319870e+07
# THOMAS W SMITH FOUNDATION INC                 1.279721e+07
# BETH AND RAVENEL CURRY FOUNDATION             1.244328e+07
# HERRICK FOUNDATION                            8.975627e+06
# Lakeside Foundation                           8.618000e+06
# HERTOG FOUNDATION                             8.183092e+06
# LILLIAN S. WELLS FOUNDATION, INC.             7.699635e+06
# Lockheed Martin Corporation                   7.399334e+06
# MERCER FAMILY FOUNDATION                      7.260673e+06
# Union Pacific                                 6.855500e+06
# Toyota                                        6.627574e+06
# EQT Corporation                               6.388915e+06
# Valero Energy Corporation                     5.919200e+06
# ADOLPH COORS FOUNDATION                       5.856684e+06
# Kiewit Mining Group                           4.824535e+06

# %%
xom_univ_df = (
    univ_df[
        [
            "carnegie_naming_cleaned",
            "recipient_city",
            "recipient_state",
            "grant_amount",
        ]
    ]
    .loc[univ_df.parent_grantmaker.isin(["ExxonMobil", "Pioneer Natural Resources"])]
    .groupby(["carnegie_naming_cleaned", "recipient_city", "recipient_state"])
    .sum()
    .reset_index()
)
xom_univ_df.columns = ["university", "city", "state", "usd"]

# %%
for i, row in xom_univ_df.iterrows():
    print(row["university"])
    latlon = city_lat_lon(city=row["city"], state=row["state"])
    xom_univ_df.loc[i, "lat"] = latlon[0]
    xom_univ_df.loc[i, "lon"] = latlon[1]

# convert to a gdf
xom_univ_gdf = df_to_gdf(xom_univ_df, lat="lat", lon="lon")
xom_univ_gdf.to_crs(exxon_gdf.crs)  # get the right crs
# Out:
# Arcadia University
# Baylor University
# Bowdoin College
# Bowie State University
# CUNY City College
# Carnegie Mellon University
# Central State University
# City University of New York
# Colorado Mesa University
# Colorado School of Mines
# Colorado State University-Fort Collins
# Columbia University in the City of New York
# Delaware State University
# Duke University
# Fairleigh Dickinson University-Metropolitan Campus
# Florida Agricultural and Mechanical University
# Florida Atlantic University
# Florida International University
# George Mason University
# George Washington University
# Georgetown University
# Georgia Institute of Technology-Main Campus
# Harvard University
# Hope College
# Howard University
# Indiana University-Bloomington
# Johns Hopkins University
# Lamar Institute of Technology
# Lamar University
# Lee College
# Lindenwood University
# Louisiana State University and Agricultural & Mechanical College
# Marietta College
# Massachusetts Institute of Technology
# Morehouse College
# New Jersey Institute of Technology
# New York University
# North Carolina A & T State University
# Northeastern State University
# Northeastern University
# Northern Illinois University
# Northern Virginia Community College
# Oregon State University
# Prairie View A & M University
# Rensselaer Polytechnic Institute
# Rice University
# Rose-Hulman Institute of Technology
# Rutgers University-New Brunswick
# Saint Louis University
# Smith College
# Southern Methodist University
# Southern University and A & M College
# Southwestern Oklahoma State University
# Spelman College
# Stanford University
# Temple University
# Texas A & M University-College Station
# Texas A & M University-Kingsville
# Texas Southern University
# Texas Tech University
# The University of Montana
# The University of Texas
# The University of Texas Health Science Center at Houston
# The University of Texas Rio Grande Valley
# The University of Texas at Arlington
# The University of Texas at Austin
# The University of Texas at Dallas
# The University of Texas at Dallas
# The University of Texas at San Antonio
# Trine University
# Tulane University of Louisiana
# United States Merchant Marine Academy
# University of Alaska Fairbanks
# University of Arizona
# University of Arkansas
# University of California-Berkeley
# University of California-San Francisco
# University of Central Florida
# University of Colorado Colorado Springs
# University of Dallas
# University of Holy Cross
# University of Houston
# University of Houston-Downtown
# University of Massachusetts-Amherst
# University of Michigan-Ann Arbor
# University of Nebraska-Lincoln
# University of North Carolina at Chapel Hill
# University of Oklahoma-Norman Campus
# University of South Alabama
# University of Southern California
# University of Southern Mississippi
# University of St Thomas
# University of Texas Southwestern Medical Center
# University of Toledo
# University of Vermont
# University of Virginia-Main Campus
# University of Washington-Seattle Campus
# University of Washington-Tacoma Campus
# University of Wyoming
# Virginia Polytechnic Institute and State University
# Washington & Jefferson College
# Washington University in St Louis
# Western Colorado University
# William & Mary
# Worcester Polytechnic Institute
# Xavier University of Louisiana
# Yale University

# %%
# Out:
#                           university           city state        usd  \
# 0                 Arcadia University       Glenside    PA   384000.0
# 1                  Baylor University           Waco    TX     2000.0
# 2                    Bowdoin College      Brunswick    ME    25000.0
# 3             Bowie State University          Bowie    MD   373840.0
# 4                  CUNY City College  New York City    NY   160000.0
# ..                               ...            ...   ...        ...
# 102      Western Colorado University       Gunnison    CO     1500.0
# 103                   William & Mary   Williamsburg    VA    15000.0
# 104  Worcester Polytechnic Institute      Worcester    MA   479800.0
# 105   Xavier University of Louisiana    New Orleans    LA  1533822.0
# 106                  Yale University      New Haven    CT    50000.0
#
#            lat         lon                     geometry
# 0    40.103196  -75.151553   POINT (-75.15155 40.10320)
# 1    31.549190  -97.147463   POINT (-97.14746 31.54919)
# 2    43.916653  -69.965944   POINT (-69.96594 43.91665)
# 3    38.942446  -76.730172   POINT (-76.73017 38.94245)
# 4    40.712728  -74.006015   POINT (-74.00602 40.71273)
# ..         ...         ...                          ...
# 102  38.647670 -107.060313  POINT (-107.06031 38.64767)
# 103  37.270879  -76.707404   POINT (-76.70740 37.27088)
# 104  42.262562  -71.801888   POINT (-71.80189 42.26256)
# 105  29.975998  -90.078213   POINT (-90.07821 29.97600)
# 106  22.266647  114.192346   POINT (114.19235 22.26665)
#
# [107 rows x 7 columns]

# %%
xom_univ_gdf.sort_values(by="usd", ascending=False).head(60)
# Out:
#                                             university              city  \
# 22                                  Harvard University         Cambridge
# 76              University of California-San Francisco     San Francisco
# 53                                     Spelman College           Atlanta
# 33               Massachusetts Institute of Technology         Cambridge
# 70                      Tulane University of Louisiana       New Orleans
# 26                            Johns Hopkins University         Baltimore
# 83                 University of Massachusetts-Amherst           Amherst
# 105                     Xavier University of Louisiana       New Orleans
# 27                       Lamar Institute of Technology          Beaumont
# 62   The University of Texas Health Science Center ...           Houston
# 19                        George Washington University        Washington
# 68              The University of Texas at San Antonio       San Antonio
# 55                                   Temple University      Philadelphia
# 35                  New Jersey Institute of Technology            Newark
# 87                University of Oklahoma-Norman Campus            Norman
# 95                  University of Virginia-Main Campus   Charlottesville
# 89                   University of Southern California       Los Angeles
# 43                       Prairie View A & M University      Prairie View
# 63           The University of Texas Rio Grande Valley          Edinburg
# 44                    Rensselaer Polytechnic Institute              Troy
# 92     University of Texas Southwestern Medical Center            Dallas
# 65                   The University of Texas at Austin            Austin
# 51               Southern University and A & M College       Baton Rouge
# 74                              University of Arkansas       Little Rock
# 64                The University of Texas at Arlington         Arlington
# 72                      University of Alaska Fairbanks         Fairbanks
# 104                    Worcester Polytechnic Institute         Worcester
# 52              Southwestern Oklahoma State University       Weatherford
# 81                               University of Houston           Houston
# 5                           Carnegie Mellon University        Pittsburgh
# 101                  Washington University in St Louis         St. Louis
# 98                               University of Wyoming           Laramie
# 6                             Central State University       Wilberforce
# 39                             Northeastern University            Boston
# 0                                   Arcadia University          Glenside
# 3                               Bowie State University             Bowie
# 79                                University of Dallas            Irving
# 54                                 Stanford University          Stanford
# 24                                   Howard University        Washington
# 50                       Southern Methodist University            Dallas
# 88                         University of South Alabama            Mobile
# 59                               Texas Tech University           Lubbock
# 78             University of Colorado Colorado Springs  Colorado Springs
# 42                             Oregon State University         Corvallis
# 48                              Saint Louis University         St. Louis
# 80                            University of Holy Cross       New Orleans
# 57                   Texas A & M University-Kingsville        Kingsville
# 21         Georgia Institute of Technology-Main Campus           Atlanta
# 23                                        Hope College           Holland
# 17                    Florida International University             Miami
# 20                               Georgetown University        Washington
# 15      Florida Agricultural and Mechanical University       Tallahassee
# 77                       University of Central Florida           Orlando
# 69                                    Trine University            Angola
# 82                      University of Houston-Downtown           Houston
# 40                        Northern Illinois University            DeKalb
# 4                                    CUNY City College     New York City
# 99   Virginia Polytechnic Institute and State Unive...        Blacksburg
# 12                           Delaware State University             Dover
# 25                      Indiana University-Bloomington       Bloomington
#
#                     state         usd        lat         lon  \
# 22                     MA  10895000.0  42.365635  -71.104002
# 76                     CA   8600000.0  37.779259 -122.419329
# 53                     GA   3308143.0  33.754466  -84.389815
# 33                     MA   2930000.0  42.365635  -71.104002
# 70                     LA   2342012.0  29.975998  -90.078213
# 26                     MD   1963000.0  39.290882  -76.610759
# 83                     MA   1700000.0  42.373195  -72.519876
# 105                    LA   1533822.0  29.975998  -90.078213
# 27                     TX   1325213.0  30.082934  -94.098428
# 62                     TX   1040000.0  29.758938  -95.367697
# 19   District of Columbia    977000.0  38.895037  -77.036543
# 68                     TX    955000.0  29.424600  -98.495141
# 55                     PA    840000.0  39.952724  -75.163526
# 35                     NJ    767856.0  40.735657  -74.172367
# 87                     OK    763125.0  35.222572  -97.439482
# 95                     VA    720000.0  38.029306  -78.476678
# 89                     CA    717870.0  34.053691 -118.242766
# 43                     TX    715072.0  30.085792  -95.990706
# 63                     TX    703000.0  26.301398  -98.162450
# 44                     NY    689908.0  42.728412  -73.691788
# 92                     TX    683300.0  32.776272  -96.796856
# 65                     TX    664000.0  30.271129  -97.743700
# 51                     LA    637421.0  28.297313  -82.502278
# 74                     AR    607207.0  34.746507  -92.289627
# 64                     TX    563000.0  32.766867  -97.099058
# 72                     AK    530000.0  64.837845 -147.716675
# 104                    MA    479800.0  42.262562  -71.801888
# 52                     OK    477870.0  35.526163  -98.707574
# 81                     TX    425250.0  29.758938  -95.367697
# 5                      PA    425000.0  40.441694  -79.990086
# 101                    MO    418657.0  38.628028  -90.191015
# 98                     WY    399991.0  32.806009 -117.070614
# 6                      OH    399842.0  39.717300  -83.885479
# 39                     MA    398418.0  42.355433  -71.060511
# 0                      PA    384000.0  40.103196  -75.151553
# 3                      MD    373840.0  38.942446  -76.730172
# 79                     TX    350000.0  32.829518  -96.944218
# 54                     CA    320000.0  37.427467 -122.170244
# 24   District of Columbia    317338.0  38.895037  -77.036543
# 50                     TX    255000.0  32.776272  -96.796856
# 88                     AL    245000.0 -33.283818  151.564697
# 59                     TX    240000.0  33.585568 -101.847021
# 78                     CO    240000.0  38.833958 -104.825348
# 42                     OR    238273.0  44.564566 -123.262044
# 48                     MO    236217.0  38.628028  -90.191015
# 80                     LA    220050.0  29.975998  -90.078213
# 57                     TX    200600.0  27.515869  -97.856109
# 21                     GA    200000.0  33.754466  -84.389815
# 23                     MI    200000.0  42.787602  -86.109083
# 17                     FL    182874.0  25.774173  -80.193620
# 20   District of Columbia    170000.0  38.895037  -77.036543
# 15                     FL    160000.0  30.438083  -84.280933
# 77                     FL    160000.0  28.547979  -81.412784
# 69                     IN    160000.0  41.634874  -84.999280
# 82                     TX    160000.0  29.758938  -95.367697
# 40                     IL    160000.0  41.890345  -88.771395
# 4                      NY    160000.0  40.712728  -74.006015
# 99                     VA    160000.0  37.229657  -80.413677
# 12                     DE    159991.0  39.158168  -75.524368
# 25                     IN    159965.0  39.167040  -86.534288
#
#                         geometry
# 22    POINT (-71.10400 42.36563)
# 76   POINT (-122.41933 37.77926)
# 53    POINT (-84.38982 33.75447)
# 33    POINT (-71.10400 42.36563)
# 70    POINT (-90.07821 29.97600)
# 26    POINT (-76.61076 39.29088)
# 83    POINT (-72.51988 42.37319)
# 105   POINT (-90.07821 29.97600)
# 27    POINT (-94.09843 30.08293)
# 62    POINT (-95.36770 29.75894)
# 19    POINT (-77.03654 38.89504)
# 68    POINT (-98.49514 29.42460)
# 55    POINT (-75.16353 39.95272)
# 35    POINT (-74.17237 40.73566)
# 87    POINT (-97.43948 35.22257)
# 95    POINT (-78.47668 38.02931)
# 89   POINT (-118.24277 34.05369)
# 43    POINT (-95.99071 30.08579)
# 63    POINT (-98.16245 26.30140)
# 44    POINT (-73.69179 42.72841)
# 92    POINT (-96.79686 32.77627)
# 65    POINT (-97.74370 30.27113)
# 51    POINT (-82.50228 28.29731)
# 74    POINT (-92.28963 34.74651)
# 64    POINT (-97.09906 32.76687)
# 72   POINT (-147.71668 64.83785)
# 104   POINT (-71.80189 42.26256)
# 52    POINT (-98.70757 35.52616)
# 81    POINT (-95.36770 29.75894)
# 5     POINT (-79.99009 40.44169)
# 101   POINT (-90.19102 38.62803)
# 98   POINT (-117.07061 32.80601)
# 6     POINT (-83.88548 39.71730)
# 39    POINT (-71.06051 42.35543)
# 0     POINT (-75.15155 40.10320)
# 3     POINT (-76.73017 38.94245)
# 79    POINT (-96.94422 32.82952)
# 54   POINT (-122.17024 37.42747)
# 24    POINT (-77.03654 38.89504)
# 50    POINT (-96.79686 32.77627)
# 88   POINT (151.56470 -33.28382)
# 59   POINT (-101.84702 33.58557)
# 78   POINT (-104.82535 38.83396)
# 42   POINT (-123.26204 44.56457)
# 48    POINT (-90.19102 38.62803)
# 80    POINT (-90.07821 29.97600)
# 57    POINT (-97.85611 27.51587)
# 21    POINT (-84.38982 33.75447)
# 23    POINT (-86.10908 42.78760)
# 17    POINT (-80.19362 25.77417)
# 20    POINT (-77.03654 38.89504)
# 15    POINT (-84.28093 30.43808)
# 77    POINT (-81.41278 28.54798)
# 69    POINT (-84.99928 41.63487)
# 82    POINT (-95.36770 29.75894)
# 40    POINT (-88.77140 41.89034)
# 4     POINT (-74.00602 40.71273)
# 99    POINT (-80.41368 37.22966)
# 12    POINT (-75.52437 39.15817)
# 25    POINT (-86.53429 39.16704)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 9))
us_gdf.plot(ax=ax, facecolor="none", edgecolor="black")
projects_gdf.loc[projects_gdf.company.isin(companies)].plot(
    ax=ax, markersize=10, color="c"
)
uic_gdf.loc[uic_gdf.facility.isin(companies)].plot(
    ax=ax, markersize=15, marker="*", color="k"
)
exxon_gdf.plot(ax=ax, markersize=10, column="infrastructure_type")
pipe_gdf.loc[pipe_gdf.prjname.isin(xom_pipe_names)].plot(ax=ax, color="g")
xom_univ_gdf.plot(ax=ax, marker=".", markersize=6, color="r")

ax.set_xlim(-125, -68)
ax.set_ylim(25, 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fig, ax = plt.subplots(1, 1, figsize=(16, 9))
#       2 us_gdf.plot(ax=ax, facecolor="none", edgecolor="black")
#       3 projects_gdf.loc[projects_gdf.company.isin(companies)].plot(
#       4     ax=ax, markersize=10, color="c"
#       5 )
#
# NameError: name 'plt' is not defined

# %%
crackers_gdf = gdf_dict["Ethylene_Crackers_US_EIA"]
crackers_gdf.COMPANY.unique()

# %%
import requests


def get_naics_code(company_name):
    # Replace spaces with '+' for the API query
    query = company_name.replace(" ", "+")
    url = (
        f"https://api.census.gov/data/2017/naics?get=NAICS,Title&for=us:*&NAICS={query}"
    )

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad responses
        data = response.json()

        # Check if data is returned
        if len(data) > 1:
            # Skip the header row and return the first result
            naics_code, title = data[1]
            return naics_code, title
        else:
            return None, "No NAICS code found for this company."

    except requests.exceptions.RequestException as e:
        return None, f"An error occurred: {e}"


if __name__ == "__main__":
    company_name = input("Enter the company name: ")
    naics_code, title = get_naics_code(company_name)

    if naics_code:
        print(f"NAICS Code: {naics_code}, Title: {title}")
    else:
        print(title)

# %%
hgl_gdf = gdf_dict["Hydrocarbon_Gas_Liquids_(HGL)_Market"]
hgl_gdf

# %%
hgl_pipeline_gdf = gdf_dict["HGL_Pipelines_US_EIA"]
hgl_pipeline_gdf.Opername.unique()

# %%
ng_gdf = gdf_dict["NaturalGas_ProcessingPlants_US_EIA"]
ng_gdf.Owner.fillna("", inplace=True)
[
    x
    for x in list(ng_gdf.Owner.unique())
    if contains_substring(x, ["exxon", "denbury", "xto", "pioneer"])
]

# %%
pipe_gdf = gpd.read_file(
    "/Volumes/T5_External/data/oilgas/ogw/ogw_pipeline_files_241121/OGWPipelines_20241121.shp"
)
pipe_gdf.columns = [replace_lots(x.lower()) for x in pipe_gdf.columns.values]

pipelines_df = pd.read_csv("/Volumes/T5_External/data/oilgas/ogw/pipelines.csv")
pipelines_df.columns = [replace_lots(x.lower()) for x in pipelines_df.columns.values]

# %%
pipelines_gdf = pipe_gdf.merge(
    pipelines_df, left_on="ogw_id", right_on="pipeline_ogw_id", how="right"
)

# %%
pipelines_gdf.company.fillna("", inplace=True)
pipeline_companies = [
    x
    for x in pipelines_gdf.company.unique()
    if contains_substring(x, ["exxon", "mobil", "denbury", "xto", "pioneer"])
]

# %%
import os


def play_ding():
    """Plays a ding on a Mac"""
    # TODO make this operating system independent
    os.system("afplay /System/Library/Sounds/Ping.aiff")

# %%
play_ding()

# %%
pipelines_df.company.fillna("", inplace=True)
sorted(list(pipelines_df.company.unique()))
# Out:
# ['',
#  'ANR Pipeline Company',
#  'Adelphia Gateway LLC',
#  'Air Liquide Large Industries US LP',
#  'Air Products Blue Energy LLC',
#  'Alaska Gasline Development Corporation',
#  'Algonquin Gas Transmission, LLC',
#  'Algonquin Gas Transmission, LLC, Maritimes & Northeast Pipeline LLC',
#  'Alliance Pipeline L.P.',
#  'Atlantic Coast Pipeline LLC, Dominion Energy Transmission Inc., Eastern Gas Transmission and Storage, Inc.',
#  'Black Bayou Gas Storage, LLC',
#  'Black Bear Transmission, LLC',
#  'Blue Marlin Offshore Port LLC',
#  'Blue Sky Infrastructure',
#  'Bluewater Gas Storage LLC',
#  'Bridger Pipeline (True Companies)',
#  'Cameron Interstate Pipeline, LLC',
#  'Capline Pipeline Company, LLC',
#  'Carolina Gas Transmission, LLC',
#  'Cheniere Corpus Christi Pipeline LP, Corpus Christi Liquefaction LLC',
#  'Cheniere Creole Trail Pipeline LP',
#  'Cheniere Energy, Inc.',
#  'Cheniere Energy, Inc., WhiteWater Midstream, Whistler Pipeline LLC',
#  'Chickahominy Power, LLC',
#  'City of Clarksville Gas & Water Department',
#  'Clearfork Midstream LLC',
#  'Columbia Gas Transmission, LLC',
#  'Columbia Gulf Transmission, LLC',
#  'Columbia Gulf Transmission, LLC, Kinder Morgan Louisiana Pipeline LLC',
#  'Commonwealth LNG LLC',
#  'ConocoPhillips',
#  'Constitution Pipeline Company LLC',
#  'Crescent Midstream',
#  'DT Midstream',
#  'Delfin LNG, LLC',
#  'Denbury Carbon Solutions LLC',
#  'Denbury Gulf Coast Pipelines, LLC',
#  'Denbury Inc.',
#  'Dominion Energy Overthrust Pipeline LLC',
#  'Dominion Energy Transmission Inc.',
#  'Dominion Energy, Inc.',
#  'Double E Pipeline LLC',
#  'Driftwood Pipeline LLC',
#  'D’Lo Gas Storage, LLC',
#  'EOG Resources, Inc.',
#  'EPIC Y-Grade, LP',
#  'EQT Corporation',
#  'East Cheyenne Gas Storage, LLC',
#  'East Tennessee Natural Gas, LLC',
#  'Eastern Gas Transmission and Storage, Inc.',
#  'Eastern Shore Natural Gas Company',
#  'El Paso Natural Gas Company, LLC',
#  'Empire Pipeline, Inc.',
#  'Empire Pipeline, Inc., National Fuel Gas Supply Corporation',
#  'EnLink Midstream LLC, 1PointFive',
#  'Enable Gas Transmission LLC',
#  'Enbridge Inc.',
#  'Enbridge Inc., Oxy Low Carbon Ventures LLC',
#  'Energy Transfer Interstate Holdings, LLC',
#  'Energy Transfer LP',
#  'Energy Transfer LP, CapturePoint Solutions, LLC',
#  'Energy Transfer LP, Enbridge Inc.',
#  'Energy Transfer Partners',
#  'Enlink CCS, LLC',
#  'Enterprise Products Operating LLC, SPOT Terminal Services LLC, Enbridge Inc.',
#  'Enterprise Products Partners',
#  'Enterprise Products Partners, Lavaca Pipe Line Company',
#  'Equitrans, LP',
#  'Equitrans, LP, Mountain Valley Pipeline LLC',
#  'Eversource Energy',
#  'ExxonMobil',
#  'ExxonMobil Oil Corporation, Sentinel Midstream, Enercoast Midstream LLC',
#  'Exxonmobil Low Carbon Logistics CCS Transport',
#  'Florida Gas Transmission Company LLC',
#  'Freeport LNG Development, L.P.',
#  'Golden Pass LNG Terminal LLC',
#  'Golden Pass LNG Terminal LLC, Golden Pass Pipeline LLC',
#  'Great Basin Gas Transmission Company',
#  'Greencore Pipeline Company LLC',
#  'Gulf Coast Express Pipeline LLC, Kinder Morgan Texas Pipeline, LLC',
#  'Gulf Run Transmission, LLC',
#  'Gulf South Pipeline Company, LP',
#  'Gulf South Pipeline Company, LP, Texas Gas Transmission, LLC',
#  'Gulfstream Natural Gas System, LLC',
#  'Hope Gas',
#  'Howard Energy Partners',
#  'Iroquois Gas Transmission System L.P.',
#  'Jordan Cove Energy Project LP, Pacific Connector Gas Pipeline LP',
#  'Jupiter Brownsville, LLC',
#  'Kern River Gas Transmission Company',
#  'Kinder Morgan Louisiana Pipeline LLC',
#  'Kinder Morgan Texas Pipeline, LLC',
#  'Kinder Morgan, Inc.',
#  'LA Storage LLC',
#  'Lower Valley Energy, Inc.',
#  'MBTC Pipeline LLC',
#  'MMEX Resources Corporation',
#  'MPLX LP, EnLink Midstream LLC, WhiteWater Midstream, Devon Energy Corp.',
#  'MPLX LP, WhiteWater Midstream, Enbridge Inc.',
#  'MPLX LP, WhiteWater Midstream, Stonepeak Infrastructure Partners, West Texas Gas, Inc.',
#  'MPLX LP, WhiteWater Midstream, WTG North Permian Midstream LLC, Rattler Midstream',
#  'Magellan Midstream Partners LP',
#  'Magellan Terminal Holdings, LP, Navigator Energy Services',
#  'Magnum Gas Storage LLC',
#  'Marathon Pipeline, Crimson Midstream',
#  'Max Midstream Texas, LLC',
#  'Midcoast Energy',
#  'Midship Pipeline Company LLC',
#  'MoGas Pipeline LLC',
#  'Moss Lake Partners',
#  'Motiva Enterprises LLC, TC Energy',
#  'Mountain Valley Pipeline LLC',
#  'MountainWest Overthrust Pipeline, LLC',
#  'NGL Energy Partners LLC',
#  'National Fuel Gas Supply Corporation',
#  'Natural Gas Pipeline Company of America, LLC',
#  'Navigator Borger Express LLC',
#  'Navigator CO2 Ventures',
#  'New Generation Gas Gathering LLC, M6 Midstream LLC, Opero Energy',
#  'Northern Border Pipeline Company',
#  'Northern Natural Gas Company',
#  'Northwest Pipeline LLC',
#  'NuStar',
#  'ONEOK, Inc.',
#  'Oil Search Alaska LLC',
#  'One Earth Sequestration LLC',
#  'Ozark Gas Transmission, LLC',
#  'PennEast Pipeline Company LLC',
#  'Pennyrile Regional Energy Authority',
#  'Permian Global Access Pipeline LLC',
#  'Permian Highway Pipeline LLC',
#  'Permico Midstream Partners LLC',
#  'Phillips 66',
#  'Phillips 66, Enbridge Inc., Energy Transfer Partners, Marathon Pipeline',
#  'Phillips 66, Harvest Midstream, PBF Logistics',
#  'Phillips 66, Trafigura JV',
#  'Plains All American',
#  'Plains All American, Holly Energy',
#  'Plains All American, Valero',
#  'Port Arthur Pipeline, LLC, Texas Connector Pipeline, LLC',
#  'Portland Natural Gas Transmission System',
#  'RH energytrans, LLC',
#  'Rio Bravo Pipeline Company, Spectra Energy Partners, LP, Enbridge Inc.',
#  'Rockies Express Pipeline, LLC',
#  'Rockies Express Pipeline, LLC, Tallgrass Energy, LP',
#  'Rockies Express Pipeline, LLC, Trailblazer Pipeline Company, LLC',
#  'Rover Pipeline LLC',
#  'Sabal Trail Transmission, LLC',
#  'Sempra Infrastructure',
#  'Sendero Carlsbad Gateway LLC',
#  'Shell Chemical Appalachia, LLC',
#  'Shell Oil Product US',
#  'Sierrita Gas Pipeline LLC',
#  'Southern Natural Gas Company LLC',
#  'Southern Star Central Gas Pipeline, Inc.',
#  'Spire STL Pipeline LLC',
#  'Summit Carbon Solutions',
#  'Sunoco Partners Marketing & Terminals, L.P., Energy Transfer Partners',
#  'TC Energy',
#  'TXGC LLC',
#  'Tallgrass Energy, LP',
#  'Targa Downstream LLC',
#  'Targa Midstream Services LLC',
#  'Targa Resources Corp.',
#  'Tenaska',
#  'Tennessee Gas Pipeline Company, LLC',
#  'Tennessee Gas Pipeline Company, LLC, Kinder Morgan, Inc.',
#  'Tennessee Gas Pipeline Company, LLC, Southern Natural Gas Company LLC',
#  'Texas Eastern Transmission, LP',
#  'Texas Gas Transmission, LLC',
#  'Texas GulfLink, LLC',
#  'TransCameron Pipeline LLC',
#  'TransMontaigne',
#  'Transcontinental Gas Pipe Line Company, LLC',
#  'Trophy Pipeline, LLC',
#  'Trunkline Gas Company LLC',
#  'Vector Pipeline L.P.',
#  'Venture Global CP Express LLC',
#  'Venture Global Delta Express LLC',
#  'Venture Global Gator Express LLC',
#  'Venture Global LNG, Inc.',
#  'Viking Gas Transmission Company',
#  'WBI Energy Transmission, Inc.',
#  'WWM Operating, LLC, Whistler Pipeline LLC',
#  'Washington Gas',
#  'West Delta LNG LLC',
#  'WhiteWater Midstream',
#  'WhiteWater Midstream, MPLX Terminals, LLC, Enbridge Inc.',
#  'Williams',
#  'Williams, Quantum Energy Partners',
#  'Wolf Carbon Solutions']

# %%
[
    x
    for x in pipe_gdf.prjname.unique()
    if contains_substring(x, ["exxon", "denbury", "xto", "pioneer", "xom", "mobil"])
]
# Out:
# ['Denbury Green Pipeline',
#  'Denbury Green to CHW Ascension Clean Energy Project']

# %%
coal_gdf = gdf_dict["CoalMines_US_EIA"]sorted()

# %%
power_gdf = gdf_dict["Power"]
print(len(power_gdf))
power_gdf = power_gdf.loc[
    (power_gdf.Coal_MW > 0) | (power_gdf.NG_MW > 0) | (power_gdf.Crude_MW > 0)
]

# %%
power_gdf["public_utility"] = [
    1
    if contains_substring(
        x,
        [
            "City of",
            "Municipal",
            "Cooperative",
            "Co-op",
            "Coop",
            "Public",
            "Power Authority",
        ],
    )
    else 0
    for x in power_gdf["Utility_Name"]
]

# %%
ng_hub_gdf = gdf_dict["Market_Hubs_Natural_Gas"]

# %%
lng_gdf = gdf_dict["Lng_ImportExportTerminals_US_EIA"]
[x for x in lng_gdf.Owner.unique() if contains_substring(x, company_list)]

# %%
crude_gdf = gdf_dict["CrudeOil_Pipelines_US_EIA"]
[x for x in crude_gdf.Opername.unique() if contains_substring(x, company_list)]

# %%
mylist = [1, 2, 3, 4]
mylist.extend([6, 7, 8])
mylist
# Out:
# [1, 2, 3, 4, 6, 7, 8]
